# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# %%
# Load dataset
df = pd.read_csv('Training Dataset/training datalist.csv')

# data cleaning
df['PPD'].fillna(0, inplace=True)
df.dropna(subset=['Voice handicap index - 10'], inplace=True)
df.reset_index(drop=True, inplace=True)

columns_to_drop = ['ID', 'Disease category', 'Diabetes', 'Hypertension', 'CAD', 'Head and Neck Cancer', 'Head injury', 'CVA', 'Onset of dysphonia ', 'Diurnal pattern']
# get certain columns as features
features = df.columns.drop(columns_to_drop).to_list()
# print(features)

# %%
# split data into train and test
from sklearn.model_selection import train_test_split

X = df[features]
y = df['Disease category']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Define your custom dataset class
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y - 1
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, index):
        try:
            tup = self.X[index].astype(np.float32), self.y[index].astype(np.int64)
        except:
            import ipdb
            ipdb.set_trace()
        return tup

# Define your model class
class Classifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(Classifier, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.2)
        self.fc2 = nn.Linear(hidden_size, hidden_size*4)
        self.fc3 = nn.Linear(hidden_size*4, num_classes)
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.fc3(out)
        return out

# %%
# Define hyperparameters
input_size = 18
hidden_size = 20
num_classes = 5
learning_rate = 0.001
batch_size = 32
num_epochs = 50

# %%
# Create your dataset and dataloader
train_dataset = CustomDataset(X_train.values, y_train.values)  # Replace X and y with your own data
test_dataset = CustomDataset(X_test.values, y_test.values)  # Replace X and y with your own data
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Create your model
model = Classifier(input_size, hidden_size, num_classes)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Training loop
for epoch in range(num_epochs):
    for batch_idx, (inputs, labels) in enumerate(train_dataloader):
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Print training progress
        if (batch_idx+1) % 10 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(train_dataloader)}], Loss: {loss.item():.4f}")
# Out:
# Epoch [1/50], Step [10/22], Loss: 1.3455
# Epoch [1/50], Step [20/22], Loss: 1.2079
# Epoch [2/50], Step [10/22], Loss: 1.2541
# Epoch [2/50], Step [20/22], Loss: 1.2030
# Epoch [3/50], Step [10/22], Loss: 1.0094
# Epoch [3/50], Step [20/22], Loss: 1.0527
# Epoch [4/50], Step [10/22], Loss: 0.9586
# Epoch [4/50], Step [20/22], Loss: 1.1019
# Epoch [5/50], Step [10/22], Loss: 1.0777
# Epoch [5/50], Step [20/22], Loss: 0.9944
# Epoch [6/50], Step [10/22], Loss: 1.3318
# Epoch [6/50], Step [20/22], Loss: 0.8980
# Epoch [7/50], Step [10/22], Loss: 1.1078
# Epoch [7/50], Step [20/22], Loss: 0.8436
# Epoch [8/50], Step [10/22], Loss: 0.7213
# Epoch [8/50], Step [20/22], Loss: 1.0679
# Epoch [9/50], Step [10/22], Loss: 1.1545
# Epoch [9/50], Step [20/22], Loss: 0.9225
# Epoch [10/50], Step [10/22], Loss: 0.9372
# Epoch [10/50], Step [20/22], Loss: 1.1264
# Epoch [11/50], Step [10/22], Loss: 0.9559
# Epoch [11/50], Step [20/22], Loss: 1.0338
# Epoch [12/50], Step [10/22], Loss: 1.4438
# Epoch [12/50], Step [20/22], Loss: 0.7372
# Epoch [13/50], Step [10/22], Loss: 0.8043
# Epoch [13/50], Step [20/22], Loss: 0.9788
# Epoch [14/50], Step [10/22], Loss: 1.0271
# Epoch [14/50], Step [20/22], Loss: 1.0800
# Epoch [15/50], Step [10/22], Loss: 0.8877
# Epoch [15/50], Step [20/22], Loss: 1.3654
# Epoch [16/50], Step [10/22], Loss: 0.9153
# Epoch [16/50], Step [20/22], Loss: 0.9362
# Epoch [17/50], Step [10/22], Loss: 1.0279
# Epoch [17/50], Step [20/22], Loss: 0.8981
# Epoch [18/50], Step [10/22], Loss: 0.7131
# Epoch [18/50], Step [20/22], Loss: 1.0005
# Epoch [19/50], Step [10/22], Loss: 0.9107
# Epoch [19/50], Step [20/22], Loss: 0.9761
# Epoch [20/50], Step [10/22], Loss: 0.7445
# Epoch [20/50], Step [20/22], Loss: 1.0300
# Epoch [21/50], Step [10/22], Loss: 0.8094
# Epoch [21/50], Step [20/22], Loss: 0.9702
# Epoch [22/50], Step [10/22], Loss: 0.9018
# Epoch [22/50], Step [20/22], Loss: 0.9725
# Epoch [23/50], Step [10/22], Loss: 0.6994
# Epoch [23/50], Step [20/22], Loss: 0.9527
# Epoch [24/50], Step [10/22], Loss: 0.7785
# Epoch [24/50], Step [20/22], Loss: 0.9114
# Epoch [25/50], Step [10/22], Loss: 1.0204
# Epoch [25/50], Step [20/22], Loss: 0.8421
# Epoch [26/50], Step [10/22], Loss: 0.8944
# Epoch [26/50], Step [20/22], Loss: 0.9343
# Epoch [27/50], Step [10/22], Loss: 0.9965
# Epoch [27/50], Step [20/22], Loss: 0.9291
# Epoch [28/50], Step [10/22], Loss: 0.8158
# Epoch [28/50], Step [20/22], Loss: 0.9563
# Epoch [29/50], Step [10/22], Loss: 0.9092
# Epoch [29/50], Step [20/22], Loss: 0.7231
# Epoch [30/50], Step [10/22], Loss: 0.8702
# Epoch [30/50], Step [20/22], Loss: 0.5974
# Epoch [31/50], Step [10/22], Loss: 0.8988
# Epoch [31/50], Step [20/22], Loss: 0.9235
# Epoch [32/50], Step [10/22], Loss: 0.9250
# Epoch [32/50], Step [20/22], Loss: 0.9243
# Epoch [33/50], Step [10/22], Loss: 0.8059
# Epoch [33/50], Step [20/22], Loss: 0.8352
# Epoch [34/50], Step [10/22], Loss: 0.8149
# Epoch [34/50], Step [20/22], Loss: 0.8527
# Epoch [35/50], Step [10/22], Loss: 0.9650
# Epoch [35/50], Step [20/22], Loss: 0.6720
# Epoch [36/50], Step [10/22], Loss: 0.8827
# Epoch [36/50], Step [20/22], Loss: 0.7131
# Epoch [37/50], Step [10/22], Loss: 1.0710
# Epoch [37/50], Step [20/22], Loss: 0.8568
# Epoch [38/50], Step [10/22], Loss: 0.7816
# Epoch [38/50], Step [20/22], Loss: 0.6996
# Epoch [39/50], Step [10/22], Loss: 0.7515
# Epoch [39/50], Step [20/22], Loss: 0.6483
# Epoch [40/50], Step [10/22], Loss: 0.7692
# Epoch [40/50], Step [20/22], Loss: 0.7145
# Epoch [41/50], Step [10/22], Loss: 0.9201
# Epoch [41/50], Step [20/22], Loss: 0.8600
# Epoch [42/50], Step [10/22], Loss: 0.7189
# Epoch [42/50], Step [20/22], Loss: 0.6409
# Epoch [43/50], Step [10/22], Loss: 0.8061
# Epoch [43/50], Step [20/22], Loss: 0.7621
# Epoch [44/50], Step [10/22], Loss: 0.7511
# Epoch [44/50], Step [20/22], Loss: 0.8375
# Epoch [45/50], Step [10/22], Loss: 0.8389
# Epoch [45/50], Step [20/22], Loss: 0.7177
# Epoch [46/50], Step [10/22], Loss: 0.6813
# Epoch [46/50], Step [20/22], Loss: 0.8641
# Epoch [47/50], Step [10/22], Loss: 0.6902
# Epoch [47/50], Step [20/22], Loss: 0.7712
# Epoch [48/50], Step [10/22], Loss: 0.6078
# Epoch [48/50], Step [20/22], Loss: 0.9552
# Epoch [49/50], Step [10/22], Loss: 0.9387
# Epoch [49/50], Step [20/22], Loss: 1.0657
# Epoch [50/50], Step [10/22], Loss: 0.9794
# Epoch [50/50], Step [20/22], Loss: 0.7981

# %%
# Evaluation
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, labels in test_dataloader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()
    
    accuracy = total_correct / total_samples
    print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.6409

# %%
# save model
torch.save(model, 'model.pth')
