# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# %%
# Load dataset
df = pd.read_csv('Training Dataset/training datalist.csv')

# data cleaning
df['PPD'].fillna(0, inplace=True)
df.dropna(subset=['Voice handicap index - 10'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
# split data into train and test
from sklearn.model_selection import train_test_split

X = df.drop(['ID', 'Disease category'], axis=1)
y = df['Disease category']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Define your custom dataset class
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y - 1
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, index):
        try:
            tup = self.X[index].astype(np.float32), self.y[index].astype(np.int64)
        except:
            import ipdb
            ipdb.set_trace()
        return tup

# Define your model class
class Classifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(Classifier, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.2)
        self.fc2 = nn.Linear(hidden_size, hidden_size*4)
        self.fc3 = nn.Linear(hidden_size*4, num_classes)
        
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.fc2(out)
        out = self.relu(out)
        out = self.dropout(out)
        out = self.fc3(out)
        return out

# %%
# Define hyperparameters
input_size = 26
hidden_size = 20
num_classes = 5
learning_rate = 0.001
batch_size = 32
num_epochs = 50

# %%
# Create your dataset and dataloader
train_dataset = CustomDataset(X_train.values, y_train.values)  # Replace X and y with your own data
test_dataset = CustomDataset(X_test.values, y_test.values)  # Replace X and y with your own data
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Create your model
model = Classifier(input_size, hidden_size, num_classes)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Training loop
for epoch in range(num_epochs):
    for batch_idx, (inputs, labels) in enumerate(train_dataloader):
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Print training progress
        if (batch_idx+1) % 10 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{batch_idx+1}/{len(train_dataloader)}], Loss: {loss.item():.4f}")
# Out:
# Epoch [1/50], Step [10/22], Loss: 1.0930
# Epoch [1/50], Step [20/22], Loss: 1.4058
# Epoch [2/50], Step [10/22], Loss: 1.6457
# Epoch [2/50], Step [20/22], Loss: 1.2392
# Epoch [3/50], Step [10/22], Loss: 1.2946
# Epoch [3/50], Step [20/22], Loss: 1.0546
# Epoch [4/50], Step [10/22], Loss: 1.4021
# Epoch [4/50], Step [20/22], Loss: 1.6898
# Epoch [5/50], Step [10/22], Loss: 1.4754
# Epoch [5/50], Step [20/22], Loss: 1.0977
# Epoch [6/50], Step [10/22], Loss: 1.1399
# Epoch [6/50], Step [20/22], Loss: 1.3630
# Epoch [7/50], Step [10/22], Loss: 1.1592
# Epoch [7/50], Step [20/22], Loss: 1.1825
# Epoch [8/50], Step [10/22], Loss: 1.0764
# Epoch [8/50], Step [20/22], Loss: 1.1282
# Epoch [9/50], Step [10/22], Loss: 1.0173
# Epoch [9/50], Step [20/22], Loss: 1.4983
# Epoch [10/50], Step [10/22], Loss: 1.1056
# Epoch [10/50], Step [20/22], Loss: 1.1618
# Epoch [11/50], Step [10/22], Loss: 1.0588
# Epoch [11/50], Step [20/22], Loss: 1.0571
# Epoch [12/50], Step [10/22], Loss: 1.4346
# Epoch [12/50], Step [20/22], Loss: 0.9036
# Epoch [13/50], Step [10/22], Loss: 1.0445
# Epoch [13/50], Step [20/22], Loss: 1.2891
# Epoch [14/50], Step [10/22], Loss: 1.0573
# Epoch [14/50], Step [20/22], Loss: 1.0536
# Epoch [15/50], Step [10/22], Loss: 1.0127
# Epoch [15/50], Step [20/22], Loss: 1.1126
# Epoch [16/50], Step [10/22], Loss: 1.1071
# Epoch [16/50], Step [20/22], Loss: 1.0743
# Epoch [17/50], Step [10/22], Loss: 1.0154
# Epoch [17/50], Step [20/22], Loss: 1.2782
# Epoch [18/50], Step [10/22], Loss: 0.8849
# Epoch [18/50], Step [20/22], Loss: 1.1013
# Epoch [19/50], Step [10/22], Loss: 1.1373
# Epoch [19/50], Step [20/22], Loss: 1.1592
# Epoch [20/50], Step [10/22], Loss: 1.1026
# Epoch [20/50], Step [20/22], Loss: 1.3218
# Epoch [21/50], Step [10/22], Loss: 1.1505
# Epoch [21/50], Step [20/22], Loss: 1.0150
# Epoch [22/50], Step [10/22], Loss: 1.0327
# Epoch [22/50], Step [20/22], Loss: 0.8480
# Epoch [23/50], Step [10/22], Loss: 0.9371
# Epoch [23/50], Step [20/22], Loss: 1.0025
# Epoch [24/50], Step [10/22], Loss: 1.5050
# Epoch [24/50], Step [20/22], Loss: 1.0616
# Epoch [25/50], Step [10/22], Loss: 0.9400
# Epoch [25/50], Step [20/22], Loss: 0.8349
# Epoch [26/50], Step [10/22], Loss: 0.6345
# Epoch [26/50], Step [20/22], Loss: 1.1587
# Epoch [27/50], Step [10/22], Loss: 1.1615
# Epoch [27/50], Step [20/22], Loss: 0.7135
# Epoch [28/50], Step [10/22], Loss: 0.7870
# Epoch [28/50], Step [20/22], Loss: 0.9148
# Epoch [29/50], Step [10/22], Loss: 1.0764
# Epoch [29/50], Step [20/22], Loss: 1.0593
# Epoch [30/50], Step [10/22], Loss: 0.6781
# Epoch [30/50], Step [20/22], Loss: 0.9081
# Epoch [31/50], Step [10/22], Loss: 0.8178
# Epoch [31/50], Step [20/22], Loss: 0.9436
# Epoch [32/50], Step [10/22], Loss: 0.9734
# Epoch [32/50], Step [20/22], Loss: 0.6867
# Epoch [33/50], Step [10/22], Loss: 0.8484
# Epoch [33/50], Step [20/22], Loss: 1.2009
# Epoch [34/50], Step [10/22], Loss: 0.9978
# Epoch [34/50], Step [20/22], Loss: 0.8531
# Epoch [35/50], Step [10/22], Loss: 0.9920
# Epoch [35/50], Step [20/22], Loss: 0.9620
# Epoch [36/50], Step [10/22], Loss: 1.4142
# Epoch [36/50], Step [20/22], Loss: 0.9634
# Epoch [37/50], Step [10/22], Loss: 0.9246
# Epoch [37/50], Step [20/22], Loss: 0.8503
# Epoch [38/50], Step [10/22], Loss: 0.8966
# Epoch [38/50], Step [20/22], Loss: 1.1071
# Epoch [39/50], Step [10/22], Loss: 0.8321
# Epoch [39/50], Step [20/22], Loss: 0.7985
# Epoch [40/50], Step [10/22], Loss: 0.7169
# Epoch [40/50], Step [20/22], Loss: 0.9482
# Epoch [41/50], Step [10/22], Loss: 1.2087
# Epoch [41/50], Step [20/22], Loss: 0.8758
# Epoch [42/50], Step [10/22], Loss: 0.9554
# Epoch [42/50], Step [20/22], Loss: 0.9630
# Epoch [43/50], Step [10/22], Loss: 0.8899
# Epoch [43/50], Step [20/22], Loss: 0.7020
# Epoch [44/50], Step [10/22], Loss: 0.7601
# Epoch [44/50], Step [20/22], Loss: 1.1924
# Epoch [45/50], Step [10/22], Loss: 1.1194
# Epoch [45/50], Step [20/22], Loss: 0.8131
# Epoch [46/50], Step [10/22], Loss: 0.8734
# Epoch [46/50], Step [20/22], Loss: 0.5965
# Epoch [47/50], Step [10/22], Loss: 0.8040
# Epoch [47/50], Step [20/22], Loss: 0.7297
# Epoch [48/50], Step [10/22], Loss: 0.7206
# Epoch [48/50], Step [20/22], Loss: 1.1112
# Epoch [49/50], Step [10/22], Loss: 1.0780
# Epoch [49/50], Step [20/22], Loss: 0.9208
# Epoch [50/50], Step [10/22], Loss: 0.8481
# Epoch [50/50], Step [20/22], Loss: 0.7045

# %%
# Evaluation
model.eval()
with torch.no_grad():
    total_correct = 0
    total_samples = 0
    for inputs, labels in test_dataloader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total_samples += labels.size(0)
        total_correct += (predicted == labels).sum().item()
    
    accuracy = total_correct / total_samples
    print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.6376
